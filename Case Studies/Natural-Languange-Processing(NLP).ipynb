# %% [markdown]
# # Natural Language Processing (NLP)
# - Identify the most frequently occuring word in the webpage to ge a clear picture of the contect of the web page

# %%
import numpy as np
import pandas as pd

# %%
data=pd.read_html('https://en.wikipedia.org/wiki/SpaceX')

# %%
data
# Out:
# [    0                                                  1
#  0 NaN  This article has multiple issues. Please help ...
#  1 NaN  This article needs attention from an expert on...
#  2 NaN  This article needs to be updated. Please updat...,
#      0                                                  1
#  0 NaN  This article needs attention from an expert on...,
#      0                                                  1
#  0 NaN  This article needs to be updated. Please updat...,
#                                                      0  \
#  0                                                 NaN
#  1   SpaceX headquarters in December 2017; plumes f...
#  2                                          Trade name
#  3                                                Type
#  4                                            Industry
#  5                                             Founded
#  6                                             Founder
#  7                                        Headquarters
# ...
